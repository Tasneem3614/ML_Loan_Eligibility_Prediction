# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d1=pd.read_csv(r"D:\Dataset\Credit_Risk_data.csv")
d1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
d1.shape
# Out:
# (614, 13)

# %%
d1.describe(include="all")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001002   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  592.000000         600.00000
# ...

# %%
d1.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
d1.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
d1.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
pd.crosstab(d1["Credit_History"],d1["Loan_Status"],margins=True)
# Out:
# Loan_Status       N    Y  All
# Credit_History
# 0.0              82    7   89
# 1.0              97  378  475
# All             179  385  564

# %%
d2=d1["Loan_ID"]
d2
# Out:
# 0      LP001002
# 1      LP001003
# 2      LP001005
# 3      LP001006
# 4      LP001008
#          ...
# 609    LP002978
# 610    LP002979
# 611    LP002983
# 612    LP002984
# 613    LP002990
# Name: Loan_ID, Length: 614, dtype: object

# %%
d3=d1.drop(["Loan_ID"],axis=1)
d3
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
d3.boxplot(['ApplicantIncome'])
# Out:
# <Axes: >

# %%
d3['CoapplicantIncome'].hist(bins=20)
# Out:
# <Axes: >

# %%
d3.boxplot(column='ApplicantIncome',by='Education')
# Out:
# <Axes: title={'center': 'ApplicantIncome'}, xlabel='Education'>

# %%
d3.boxplot(column='LoanAmount')
# Out:
# <Axes: title={'center': 'ApplicantIncome'}, xlabel='Education'>

# %%
d3.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
d3.Gender.value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
d3.Gender=d3.Gender.fillna("Female")

# %% [markdown]
# #### Missing value

# %%
d3.isnull().sum()
# Out:
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
d3.Self_Employed.value_counts()
# Out:
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64

# %%
d3.Loan_Status.value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
d3.Self_Employed=d3.Self_Employed.fillna("Yes")

# %%
d3.isnull().sum()
# Out:
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
d3.Married.value_counts()
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
d3.Married=d3.Married.fillna("No")

# %%
d3.isnull().sum()
# Out:
# Gender                0
# Married               0
# Dependents           15
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
d3.Dependents.value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
d3.Dependents=d3.Dependents.fillna("3+")

# %%
d3.Dependents.value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     66
# Name: count, dtype: int64

# %%
d3.isnull().sum()
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# d3.LoanAmount.value_counts()

# %%
d3.Credit_History.value_counts() #converted data type credit_history ori
# Out:
# Credit_History
# 1.0    475
# 0.0     89
# Name: count, dtype: int64

# %%
d3.Credit_History=d3.Credit_History.fillna(0.0)

# %%
d3.Credit_History.value_counts() #converted data type credit_history ori
# Out:
# Credit_History
# 1.0    475
# 0.0    139
# Name: count, dtype: int64

# %%
d3.isnull().sum()
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
d3.Loan_Amount_Term.value_counts()
# Out:
# Loan_Amount_Term
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %%
d3.Loan_Amount_Term=d3.Loan_Amount_Term.fillna(12.0) #even do it is a float type but it is a discrete value and has category

# %%
d3.isnull().sum()
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# #### Numerical imputing

# %%
d3.LoanAmount.value_counts()
# Out:
# LoanAmount
# 120.0    20
# 110.0    17
# 100.0    15
# 160.0    12
# 187.0    12
#          ..
# 240.0     1
# 214.0     1
# 59.0      1
# 166.0     1
# 253.0     1
# Name: count, Length: 203, dtype: int64

# %%
d3.LoanAmount=d3.LoanAmount.fillna(d3.LoanAmount.median())

# %%
d3.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
d3.dtypes
# Out:
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %% [markdown]
# #### Data type conversion

# %%
d3
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
d3.dtypes
# Out:
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
d3.Gender=le.fit_transform(d3.Gender)

# %%
d3.Gender.value_counts()
# Out:
# Gender
# 1    489
# 0    125
# Name: count, dtype: int64

# %%
d3.Married=le.fit_transform(d3.Married)

# %%
d3.Married.value_counts()
# Out:
# Married
# 1    398
# 0    216
# Name: count, dtype: int64

# %%
d3.Dependents=le.fit_transform(d3.Dependents)

# %%
d3.Dependents.value_counts()
# Out:
# Dependents
# 0    345
# 1    102
# 2    101
# 3     66
# Name: count, dtype: int64

# %%
d3.Education=le.fit_transform(d3.Education)

# %%
d3.Education.value_counts()
# Out:
# Education
# 0    480
# 1    134
# Name: count, dtype: int64

# %%
d3.Self_Employed=le.fit_transform(d3.Self_Employed)

# %%
d3.Self_Employed.value_counts()
# Out:
# Self_Employed
# 0    500
# 1    114
# Name: count, dtype: int64

# %%
d3.Property_Area=le.fit_transform(d3.Property_Area)

# %%
d3.Property_Area.value_counts()
# Out:
# Property_Area
# 1    233
# 2    202
# 0    179
# Name: count, dtype: int64

# %%
d3.Loan_Status=le.fit_transform(d3.Loan_Status)

# %%
d3
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %% [markdown]
# #### Duplicate checking

# %%
d3.shape
# Out:
# (614, 12)

# %%
d3.drop_duplicates(inplace=True)

# %%
d3.shape
# Out:
# (614, 12)

# %%
d3.dtypes
# Out:
# Gender                 int32
# Married                int32
# Dependents             int32
# Education              int32
# Self_Employed          int32
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int32
# Loan_Status            int32
# dtype: object

# %%
d3.skew()
# Out:
# Gender              -1.475893
# Married             -0.622252
# Dependents           0.912335
# Education            1.367622
# Self_Employed        1.620738
# ApplicantIncome      6.539513
# CoapplicantIncome    7.491531
# LoanAmount           2.743053
# Loan_Amount_Term    -2.460484
# Credit_History      -1.310835
# Property_Area       -0.066196
# Loan_Status         -0.809998
# dtype: float64

# %%
d3.Loan_Status.value_counts()
# Out:
# Loan_Status
# 1    422
# 0    192
# Name: count, dtype: int64

# %% [markdown]
# #### EDA---

# %%
d3.dtypes
# Out:
# Gender                 int32
# Married                int32
# Dependents             int32
# Education              int32
# Self_Employed          int32
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int32
# Loan_Status            int32
# dtype: object

# %%
d3.head(15)
# Out:
#     Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0        1        0           0          0              0             5849
# 1        1        1           1          0              0             4583
# 2        1        1           0          0              1             3000
# 3        1        1           0          1              0             2583
# 4        1        0           0          0              0             6000
# 5        1        1           2          0              1             5417
# 6        1        1           0          1              0             2333
# 7        1        1           3          0              0             3036
# 8        1        1           2          0              0             4006
# 9        1        1           1          0              0            12841
# 10       1        1           2          0              0             3200
# ...

# %%
import seaborn as sns
sns.barplot(x="Gender",y="Loan_Status",data=d3)
# a bar plot showing the loan status (approved or not) for each gender category.
# Out:
# <Axes: title={'center': 'ApplicantIncome'}, xlabel='Education', ylabel='Loan_Status'>

# %%
sns.scatterplot(x="ApplicantIncome",y="LoanAmount",data=d3)
#applicaincome is then load amount is also less
# Out:
# <Axes: title={'center': 'ApplicantIncome'}, xlabel='Education', ylabel='Loan_Status'>

# %%
sns.lmplot(x="ApplicantIncome",y="LoanAmount",data=d3)

# %%
sns.histplot(data=d3,x="LoanAmount")
#it gives the count for loanamount
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %%
d3.dtypes
# Out:
# Gender                 int32
# Married                int32
# Dependents             int32
# Education              int32
# Self_Employed          int32
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int32
# Loan_Status            int32
# dtype: object

# %%
sns.distplot(d3["LoanAmount"])
# Out:
# <Axes: xlabel='LoanAmount', ylabel='LoanAmount'>

# %%
d1=d3.corr()
d1
# Out:
#                      Gender   Married  Dependents  Education  Self_Employed  \
# Gender             1.000000  0.339026    0.141975   0.061497      -0.039440
# Married            0.339026  1.000000    0.307667   0.017671      -0.016628
# Dependents         0.141975  0.307667    1.000000   0.061179       0.030808
# Education          0.061497  0.017671    0.061179   1.000000      -0.019059
# Self_Employed     -0.039440 -0.016628    0.030808  -0.019059       1.000000
# ApplicantIncome    0.013933  0.050194    0.110073  -0.140760       0.121356
# CoapplicantIncome  0.082316  0.080496    0.016073  -0.062290       0.028834
# LoanAmount         0.063245  0.145717    0.140926  -0.168759       0.112103
# Loan_Amount_Term  -0.053248 -0.081051   -0.037612  -0.108617      -0.038786
# Credit_History     0.035780 -0.023626   -0.034355  -0.081637      -0.001923
# Property_Area     -0.017054  0.000395    0.025773  -0.065243      -0.022732
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
heatmap=sns.heatmap(d1,linewidth=1,annot=True)

# %%
sns.barplot(x="Credit_History",y="Loan_Status",data=d3)
#high credict history has more chances of loan
# Out:
# <Axes: xlabel='Credit_History', ylabel='Loan_Status'>

# %%
sns.barplot(x="Loan_Status",y="LoanAmount",hue="Self_Employed",data=d3)
# Out:
# <Axes: xlabel='Credit_History', ylabel='Loan_Status'>

# %%
sns.kdeplot(data=d3,x="LoanAmount",hue="Married",fill=True,alpha=0.6,linewidth=1.5)
# Out:
# <Axes: xlabel='Credit_History', ylabel='Loan_Status'>

# %%
#Outliear treatment

# %%
d3.LoanAmount.skew()
# Out:
# 2.743052748820892

# %%
sns.boxplot(data=d3,y="LoanAmount")
# Out:
# <Axes: xlabel='Credit_History', ylabel='Loan_Status'>

# %%
plt.hist(d3["LoanAmount"])
# Out:
# (array([ 72., 332., 143.,  33.,  15.,   6.,   5.,   3.,   3.,   2.]),
#  array([  9. ,  78.1, 147.2, 216.3, 285.4, 354.5, 423.6, 492.7, 561.8,
#         630.9, 700. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(d3["LoanAmount"])
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Loan_Status'>

# %%
d3["LoanAmount"].describe()
# Out:
# count    614.000000
# mean     145.752443
# std       84.107233
# min        9.000000
# 25%      100.250000
# 50%      128.000000
# 75%      164.750000
# max      700.000000
# Name: LoanAmount, dtype: float64

# %%
IQR=d3.LoanAmount.quantile(0.75)-d3.LoanAmount.quantile(0.25)
IQR
# Out:
# 64.5

# %%
up1=d3.LoanAmount.quantile(0.75)+(3*IQR)
up1
# Out:
# 358.25

# %%
d3.loc[d3["LoanAmount"]>358.25,"LoanAmount"]=358.25

# %%
plt.hist(d3["LoanAmount"])
# Out:
# (array([ 12.,  60., 153., 181.,  92.,  50.,  15.,  18.,  10.,  23.]),
#  array([  9.   ,  43.925,  78.85 , 113.775, 148.7  , 183.625, 218.55 ,
#         253.475, 288.4  , 323.325, 358.25 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(d3["LoanAmount"])
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Loan_Status'>

# %%
d3.LoanAmount.skew()
# Out:
# 1.4068977534886449

# %%
# ApplicantIncome        
# CoapplicantIncome
sns.boxplot(data=d3,y="ApplicantIncome")
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Loan_Status'>

# %%
sns.histplot(d3["ApplicantIncome"])
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Loan_Status'>

# %%
sns.distplot(d3["ApplicantIncome"])
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Loan_Status'>

# %%
d3["ApplicantIncome"].describe()
# Out:
# count      614.000000
# mean      5403.459283
# std       6109.041673
# min        150.000000
# 25%       2877.500000
# 50%       3812.500000
# 75%       5795.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %%
iqr=d3.ApplicantIncome.quantile(0.75)-d3.ApplicantIncome.quantile(0.25)
iqr
# Out:
# 2917.5

# %%
up2=d3.ApplicantIncome.quantile(0.75)+(3*iqr)
up2
# Out:
# 14547.5

# %%
d3.loc[d3["ApplicantIncome"]>14547.5,"ApplicantIncome"]=14547.5

# %%
sns.histplot(d3["ApplicantIncome"])
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Loan_Status'>

# %%
sns.distplot(d3["ApplicantIncome"])
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Loan_Status'>

# %%
sns.boxplot(data=d3,y="CoapplicantIncome")
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Loan_Status'>

# %%
sns.histplot(d3["CoapplicantIncome"])
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Loan_Status'>

# %%
sns.distplot(d3["CoapplicantIncome"])
# Out:
# <Axes: xlabel='CoapplicantIncome', ylabel='Loan_Status'>

# %%
d3["CoapplicantIncome"].describe()
# Out:
# count      614.000000
# mean      1621.245798
# std       2926.248369
# min          0.000000
# 25%          0.000000
# 50%       1188.500000
# 75%       2297.250000
# max      41667.000000
# Name: CoapplicantIncome, dtype: float64

# %%
iqr1=d3.CoapplicantIncome.quantile(0.75)-d3.CoapplicantIncome.quantile(0.25)
iqr1
# Out:
# 2297.25

# %%
upr=d3.CoapplicantIncome.quantile(0.75)+(3*iqr1)
upr
# Out:
# 9189.0

# %%
d3.loc[d3["CoapplicantIncome"]>9189.0,"CoapplicantIncome"]=9189.0

# %%
sns.histplot(d3["CoapplicantIncome"])
# Out:
# <Axes: xlabel='CoapplicantIncome', ylabel='Loan_Status'>

# %%
sns.distplot(d3["CoapplicantIncome"])
# Out:
# <Axes: xlabel='CoapplicantIncome', ylabel='Loan_Status'>

# %%
# age....
# length of service..
# avg_train_score

# %%
# iqr1=d3.CoapplicantIncome.quantile(0.75)-d3.CoapplicantIncome.quantile(0.25)
# iqr1
# upr=d3.CoapplicantIncome.quantile(0.75)+(3*iqr1)
# upr
# d3.loc[d3["CoapplicantIncome"]>9189.0,"CoapplicantIncome"]=9189.0

# %%
#skewness treatment

# %%
d3.skew()
# Out:
# Gender              -1.475893
# Married             -0.622252
# Dependents           0.912335
# Education            1.367622
# Self_Employed        1.620738
# ApplicantIncome      1.710913
# CoapplicantIncome    1.657233
# LoanAmount           1.406898
# Loan_Amount_Term    -2.460484
# Credit_History      -1.310835
# Property_Area       -0.066196
# Loan_Status         -0.809998
# dtype: float64

# %% [raw]
# #if data is positively skewd we have log tramsformation, square root,cube tranformation
# #if data is negatively skew we use square transform

# %%
#logirithmic Transformation-------------
import numpy as np

# %%
d3.shape
# Out:
# (614, 12)

# %%
# dd=d3[d3.ApplicantIncome>0]

# %%
# dd.shape

# %%
# d1=np.log(d3.ApplicantIncome)

# %%
# d1.skew()

# %%
# sns.distplot(d1)

# %% [markdown]
# # Squareroot Transformation---------------

# %%
#d3.ApplicantIncome=np.sqrt["ApplicantIncome"]

# %%
# d3.skew()

# %%
# sns.distplot(np.sqrt(d3["ApplicantIncome"]))

# %%
d3.ApplicantIncome=np.cbrt(d3["ApplicantIncome"])

# %%
d3.skew()
# Out:
# Gender              -1.475893
# Married             -0.622252
# Dependents           0.912335
# Education            1.367622
# Self_Employed        1.620738
# ApplicantIncome      0.749049
# CoapplicantIncome    1.657233
# LoanAmount           1.406898
# Loan_Amount_Term    -2.460484
# Credit_History      -1.310835
# Property_Area       -0.066196
# Loan_Status         -0.809998
# dtype: float64

# %%
sns.distplot(np.cbrt(d3["ApplicantIncome"]))
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Loan_Status'>

# %%
dd1=d3[d3.CoapplicantIncome>0]

# %%
d3.CoapplicantIncome=np.cbrt(d3["CoapplicantIncome"])

# %%
d3.skew()
# Out:
# Gender              -1.475893
# Married             -0.622252
# Dependents           0.912335
# Education            1.367622
# Self_Employed        1.620738
# ApplicantIncome      0.749049
# CoapplicantIncome    0.031444
# LoanAmount           1.406898
# Loan_Amount_Term    -2.460484
# Credit_History      -1.310835
# Property_Area       -0.066196
# Loan_Status         -0.809998
# dtype: float64

# %%
dd2=d3[d3.LoanAmount>0]

# %%
dd2.shape
# Out:
# (614, 12)

# %%
d3.LoanAmount=np.cbrt(d3["LoanAmount"])

# %%
sns.distplot(d3["LoanAmount"])
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Loan_Status'>

# %%
d3.skew()
# Out:
# Gender              -1.475893
# Married             -0.622252
# Dependents           0.912335
# Education            1.367622
# Self_Employed        1.620738
# ApplicantIncome      0.749049
# CoapplicantIncome    0.031444
# LoanAmount           0.270853
# Loan_Amount_Term    -2.460484
# Credit_History      -1.310835
# Property_Area       -0.066196
# Loan_Status         -0.809998
# dtype: float64

# %%
d3.Loan_Status.value_counts()
# Out:
# Loan_Status
# 1    422
# 0    192
# Name: count, dtype: int64

# %%
d3.shape
# Out:
# (614, 12)

# %%
d3.head(2)
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0        18.017473
# 1       1        1           1          0              0        16.610522
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0           0.000000    5.039684             360.0             1.0
# 1          11.467457    5.039684             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              2            1
# 1              0            0

# %%
x=d3.iloc[:,0:11]
y=d3.iloc[:,-1]
# y.head(2)

# %%
from sklearn.model_selection import train_test_split

# %%
c_x_train,c_x_test,c_y_train,c_y_test=train_test_split(x,y,test_size=0.2,random_state=101)

# %%
c_x_train.shape,c_x_test.shape,c_y_train.shape,c_y_test.shape
# Out:
# ((491, 11), (123, 11), (491,), (123,))

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lg= LogisticRegression()

# %%
lg.fit(c_x_train,c_y_train)
# Out:
# LogisticRegression()

# %%
p1=lg.predict(c_x_test)

# %%
p_value=lg.predict_proba(c_x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
m1=confusion_matrix(p1,c_y_test)
m1
# Out:
# array([[23, 10],
#        [22, 68]], dtype=int64)

# %%
ac1=m1.diagonal().sum()/m1.sum()*100
ac1
# Out:
# 73.98373983739837

# %%
from sklearn.metrics import classification_report
print(classification_report(p1,c_y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.70      0.59        33
#            1       0.87      0.76      0.81        90
#
#     accuracy                           0.74       123
#    macro avg       0.69      0.73      0.70       123
# weighted avg       0.78      0.74      0.75       123

# %%
d3.Loan_Status.value_counts()
# Out:
# Loan_Status
# 1    422
# 0    192
# Name: count, dtype: int64

# %% [markdown]
# #### precidion recall curve

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score

# %%
precision,recall,threshold=precision_recall_curve(c_y_test,df.iloc[:,1])

# %%
precision
# Out:
# array([0.63414634, 0.63114754, 0.63636364, 0.63333333, 0.63865546,
#        0.63559322, 0.64102564, 0.64655172, 0.65217391, 0.64912281,
#        0.65486726, 0.66071429, 0.66666667, 0.67272727, 0.66972477,
#        0.67592593, 0.68224299, 0.68867925, 0.6952381 , 0.70192308,
#        0.70873786, 0.70588235, 0.71287129, 0.72      , 0.71717172,
#        0.71428571, 0.72164948, 0.71875   , 0.72631579, 0.73404255,
#        0.74193548, 0.75      , 0.74725275, 0.75555556, 0.75280899,
#        0.76136364, 0.77011494, 0.76744186, 0.76470588, 0.76190476,
#        0.75903614, 0.75609756, 0.75308642, 0.75      , 0.75949367,
#        0.75641026, 0.76623377, 0.76315789, 0.77333333, 0.78378378,
#        0.78082192, 0.77777778, 0.78873239, 0.78571429, 0.79710145,
#        0.79411765, 0.79104478, 0.78787879, 0.8       , 0.796875  ,
#        0.79365079, 0.80645161, 0.80327869, 0.8       , 0.79661017,
#        0.79310345, 0.78947368, 0.78571429, 0.78181818, 0.77777778,
# ...

# %%
recall
# Out:
# array([1.        , 0.98717949, 0.98717949, 0.97435897, 0.97435897,
#        0.96153846, 0.96153846, 0.96153846, 0.96153846, 0.94871795,
#        0.94871795, 0.94871795, 0.94871795, 0.94871795, 0.93589744,
#        0.93589744, 0.93589744, 0.93589744, 0.93589744, 0.93589744,
#        0.93589744, 0.92307692, 0.92307692, 0.92307692, 0.91025641,
#        0.8974359 , 0.8974359 , 0.88461538, 0.88461538, 0.88461538,
#        0.88461538, 0.88461538, 0.87179487, 0.87179487, 0.85897436,
#        0.85897436, 0.85897436, 0.84615385, 0.83333333, 0.82051282,
#        0.80769231, 0.79487179, 0.78205128, 0.76923077, 0.76923077,
#        0.75641026, 0.75641026, 0.74358974, 0.74358974, 0.74358974,
#        0.73076923, 0.71794872, 0.71794872, 0.70512821, 0.70512821,
#        0.69230769, 0.67948718, 0.66666667, 0.66666667, 0.65384615,
#        0.64102564, 0.64102564, 0.62820513, 0.61538462, 0.6025641 ,
#        0.58974359, 0.57692308, 0.56410256, 0.55128205, 0.53846154,
# ...

# %%
threshold
# Out:
# array([0.18390899, 0.20952979, 0.23291445, 0.2413021 , 0.25699222,
#        0.26668433, 0.28015805, 0.28033513, 0.29064181, 0.2942878 ,
#        0.29818177, 0.29975787, 0.30120641, 0.30455954, 0.30515007,
#        0.32516148, 0.33048562, 0.33228493, 0.35025089, 0.35852563,
#        0.36054752, 0.36690344, 0.39661164, 0.405555  , 0.41290791,
#        0.41667008, 0.41833841, 0.44019487, 0.45117928, 0.45413311,
#        0.48450999, 0.48758604, 0.49391209, 0.66021608, 0.662     ,
#        0.66976909, 0.69995418, 0.70630495, 0.70748412, 0.70982176,
#        0.71735473, 0.71922738, 0.72120985, 0.72321084, 0.7240214 ,
#        0.72537973, 0.73294776, 0.73398765, 0.7345809 , 0.73563042,
#        0.73832816, 0.73963337, 0.74614523, 0.75024561, 0.75368946,
#        0.75504446, 0.75506313, 0.75649209, 0.75783961, 0.75899995,
#        0.7621297 , 0.76337619, 0.76527777, 0.7659096 , 0.76649649,
#        0.7667236 , 0.76707759, 0.77162107, 0.77201664, 0.77607599,
# ...

# %%
plt.plot(recall,precision,label="PRC")
plt.xlabel("recall")
plt.ylabel("precision")
plt.legend(loc="upper right")
plt.title("precision-recall")
# Out:
# Text(0.5, 1.0, 'precision-recall')

# %% [markdown]
# #### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(c_x_train,c_y_train)
# Out:
# DecisionTreeClassifier()

# %%
d_p=dt.predict(c_x_test)

# %%
d_m=confusion_matrix(d_p,c_y_test)
d_m
# Out:
# array([[23, 24],
#        [22, 54]], dtype=int64)

# %%
d_acc=d_m.diagonal().sum()/d_m.sum()*100
d_acc
# Out:
# 62.601626016260155

# %%
print(classification_report(d_p,c_y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.49      0.50        47
#            1       0.69      0.71      0.70        76
#
#     accuracy                           0.63       123
#    macro avg       0.60      0.60      0.60       123
# weighted avg       0.62      0.63      0.62       123

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(c_x_train,c_y_train)
# Out:
# RandomForestClassifier()

# %%
rp=rf.predict(c_x_test)

# %%
r_m=confusion_matrix(rp,c_y_test)
r_m
# Out:
# array([[22, 10],
#        [23, 68]], dtype=int64)

# %%
ra_acc2=r_m.diagonal().sum()/r_m.sum()*100
ra_acc2
# Out:
# 73.17073170731707

# %%
print(classification_report(rp,c_y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.69      0.57        32
#            1       0.87      0.75      0.80        91
#
#     accuracy                           0.73       123
#    macro avg       0.68      0.72      0.69       123
# weighted avg       0.77      0.73      0.74       123

# %% [markdown]
# #### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier(n_neighbors=40)

# %%
knn.fit(c_x_train,c_y_train)
# Out:
# KNeighborsClassifier(n_neighbors=40)

# %%
kp=knn.predict(c_x_test)

# %%
k_c=confusion_matrix(kp,c_y_test)
k_c
# Out:
# array([[ 0,  0],
#        [45, 78]], dtype=int64)

# %%
k_acc=k_c.diagonal().sum()/k_c.sum()*100
k_acc
# Out:
# 63.41463414634146

# %%
print(classification_report(kp,c_y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.63      0.78       123
#
#     accuracy                           0.63       123
#    macro avg       0.50      0.32      0.39       123
# weighted avg       1.00      0.63      0.78       123

# %%
lst=list()

# %%
for i in range(1,60):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(c_x_train,c_y_train)
    knn_p=knn.predict(c_x_test)
    c=confusion_matrix(knn_p,c_y_test)
    acc=c.diagonal().sum()/c.sum()*100
    lst.append(acc)

# %%
p=plt.plot(lst)

# %% [markdown]
# #### SVM

# %%
from sklearn.svm import SVC
svc=SVC()

# %%
svc.fit(c_x_train,c_y_train)
# Out:
# SVC()

# %%
sp=svc.predict(c_x_test)

# %%
sm=confusion_matrix(sp,c_y_test)
sm
# Out:
# array([[ 0,  0],
#        [45, 78]], dtype=int64)

# %%
s_acc=sm.diagonal().sum()/sm.sum()*100
s_acc
# Out:
# 63.41463414634146

# %%
print(classification_report(sp,c_y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.63      0.78       123
#
#     accuracy                           0.63       123
#    macro avg       0.50      0.32      0.39       123
# weighted avg       1.00      0.63      0.78       123

# %% [markdown]
# #### naivebyes

# %%
from sklearn.naive_bayes import MultinomialNB
nb=MultinomialNB()

# %%
nb.fit(c_x_train,c_y_train)
# Out:
# MultinomialNB()

# %%
np=nb.predict(c_x_test)

# %%
nb_m=confusion_matrix(np,c_y_test)
nb_m
# Out:
# array([[ 2,  2],
#        [43, 76]], dtype=int64)

# %%
n_acc=nb_m.diagonal().sum()/nb_m.sum()*100
n_acc
# Out:
# 63.41463414634146

# %%
print(classification_report(np,c_y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.04      0.50      0.08         4
#            1       0.97      0.64      0.77       119
#
#     accuracy                           0.63       123
#    macro avg       0.51      0.57      0.43       123
# weighted avg       0.94      0.63      0.75       123

# %% [markdown]
# #### conclusion before class imbalance Logistic regression is given the best result

# %% [markdown]
# # Imbalance Techniques

# %%
d3.Loan_Status.value_counts()
# Out:
# Loan_Status
# 1    422
# 0    192
# Name: count, dtype: int64

# %%
d3.shape
# Out:
# (614, 12)

# %% [markdown]
# #### my data is having a class imbalance issue so i have applied all the class imbalance techniques from that smote is give the good result.

# %%
from imblearn.over_sampling import SMOTE
smote=SMOTE()

# %%
x_sm,y_sm=smote.fit_resample(x,y)

# %%
x_sm.shape,y_sm.shape
# Out:
# ((844, 11), (844,))

# %%
y_sm.value_counts()
# Out:
# Loan_Status
# 1    422
# 0    422
# Name: count, dtype: int64

# %%
x1_tr,x1_te,y1_tr,y1_te=train_test_split(x_sm,y_sm,test_size=0.2,random_state=101)

# %%
x1_tr.shape,x1_te.shape,y1_tr.shape,y1_te.shape
# Out:
# ((675, 11), (169, 11), (675,), (169,))

# %% [markdown]
# #### Logistic regression

# %%
lg.fit(x1_tr,y1_tr)
# Out:
# LogisticRegression()

# %%
op1=lg.predict(x1_te)

# %%
om=confusion_matrix(op1,y1_te)
om
# Out:
# array([[54, 14],
#        [38, 63]], dtype=int64)

# %%
o_ac=om.diagonal().sum()/om.sum()*100
o_ac
# Out:
# 69.23076923076923

# %%
print(classification_report(op1,y1_te)) #smote
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.79      0.68        68
#            1       0.82      0.62      0.71       101
#
#     accuracy                           0.69       169
#    macro avg       0.70      0.71      0.69       169
# weighted avg       0.73      0.69      0.69       169

# %% [markdown]
# #### DecisionTree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(x1_tr,y1_tr)
# Out:
# DecisionTreeClassifier()

# %%
d_p=dt.predict(x1_te)

# %%
d_m=confusion_matrix(d_p,y1_te)
d_m
# Out:
# array([[66, 17],
#        [26, 60]], dtype=int64)

# %%
d_acc=d_m.diagonal().sum()/d_m.sum()*100
d_acc
# Out:
# 74.55621301775149

# %%
print(classification_report(d_p,y1_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.80      0.75        83
#            1       0.78      0.70      0.74        86
#
#     accuracy                           0.75       169
#    macro avg       0.75      0.75      0.75       169
# weighted avg       0.75      0.75      0.75       169

# %% [markdown]
# #### RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(x1_tr,y1_tr)
# Out:
# RandomForestClassifier()

# %%
r_p=dt.predict(x1_te)

# %%
r_m=confusion_matrix(d_p,y1_te)
r_m
# Out:
# array([[66, 17],
#        [26, 60]], dtype=int64)

# %%
r_acc=d_m.diagonal().sum()/d_m.sum()*100
r_acc
# Out:
# 74.55621301775149

# %%
print(classification_report(r_p,y1_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.80      0.75        83
#            1       0.78      0.70      0.74        86
#
#     accuracy                           0.75       169
#    macro avg       0.75      0.75      0.75       169
# weighted avg       0.75      0.75      0.75       169

# %% [markdown]
# #### knn

# %%
from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier(n_neighbors=40)

# %%
knn.fit(x1_tr,y1_tr)
# Out:
# KNeighborsClassifier(n_neighbors=40)

# %%
kp=knn.predict(x1_te)

# %%
k_c=confusion_matrix(kp,y1_te)
k_c
# Out:
# array([[65, 31],
#        [27, 46]], dtype=int64)

# %%
k_acc=k_c.diagonal().sum()/k_c.sum()*100
k_acc
# Out:
# 65.68047337278107

# %%
print(classification_report(kp,y1_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.68      0.69        96
#            1       0.60      0.63      0.61        73
#
#     accuracy                           0.66       169
#    macro avg       0.65      0.65      0.65       169
# weighted avg       0.66      0.66      0.66       169

# %%
lst1=list()

# %%
for i in range(1,60):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x1_tr,y1_tr)
    knn_p=knn.predict(x1_te)
    c=confusion_matrix(knn_p,y1_te)
    acc=c.diagonal().sum()/c.sum()*100
    lst1.append(acc)

# %%
p1=plt.plot(lst1)

# %% [markdown]
# #### SVM

# %%
from sklearn.svm import SVC
svc=SVC()

# %%
svc.fit(x1_tr,y1_tr)
# Out:
# SVC()

# %%
sp=svc.predict(x1_te)

# %%
sm=confusion_matrix(sp,y1_te)
sm
# Out:
# array([[ 6,  3],
#        [86, 74]], dtype=int64)

# %%
s_acc=sm.diagonal().sum()/sm.sum()*100
s_acc
# Out:
# 47.337278106508876

# %%
print(classification_report(sp,y1_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.07      0.67      0.12         9
#            1       0.96      0.46      0.62       160
#
#     accuracy                           0.47       169
#    macro avg       0.51      0.56      0.37       169
# weighted avg       0.91      0.47      0.60       169

# %% [markdown]
# #### NaiveBayes

# %%
from sklearn.naive_bayes import MultinomialNB
nb=MultinomialNB()

# %%
nb.fit(x1_tr,y1_tr)
# Out:
# MultinomialNB()

# %%
np=nb.predict(x1_te)

# %%
nb_m=confusion_matrix(np,y1_te)
nb_m
# Out:
# array([[49, 31],
#        [43, 46]], dtype=int64)

# %%
n_acc=nb_m.diagonal().sum()/nb_m.sum()*100
n_acc
# Out:
# 56.213017751479285

# %%
print(classification_report(np,y1_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.61      0.57        80
#            1       0.60      0.52      0.55        89
#
#     accuracy                           0.56       169
#    macro avg       0.57      0.56      0.56       169
# weighted avg       0.57      0.56      0.56       169

# %% [markdown]
# ####  conclusion is after applying all the techniques Random forest is given me the best result or Accuracy.
